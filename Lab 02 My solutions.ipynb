# %% [markdown]
# # Lab 2 - My solutions
# **Graphical representation of functions**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Yehor" # Write your name between parenthesis
student_id = 2602063 # Change your student ID here
date_returned = "04.03.2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display
import numpy as np
import matplotlib.pyplot as plt
import labx as mx # Remenber to donwload labx.pyc from the course website

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
x = np.linspace(-10, 10, 1000)
y = mx.lab_2_problem_1(x, student_id)
plt.figure()
plt.plot(x,y, label='Graph')
plt.title("Overview: All roots visible")
plt.axhline(y=0, color='r')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.legend()
plt.show()

plt.plot(x,y, label='First zoom')
plt.title("First root")
plt.axhline(y=0, color='r')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-5.275, -5.175)
plt.ylim(-2,2)
plt.grid(True)
plt.legend()
plt.show()

plt.plot(x,y, label='Second zoom')
plt.axhline(y=0, color='r')
plt.title("Second root")
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-3.43, -3.38)
plt.ylim(-0.01,0.01)
plt.grid(True)
plt.legend()
plt.show()

plt.plot(x,y, label='Third zoom')
plt.title("Third root")
plt.axhline(y=0, color='r')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-3.1, -2.8)
plt.ylim(-0.3,0.3)
plt.grid(True)
plt.legend()
plt.show()

plt.plot(x,y, label='Forth zoom')
plt.title("Forth root")
plt.axhline(y=0, color='r')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-2.5, -2.15)
plt.ylim(-0.05,0.05)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ## Problem 2

# %%
# Run the code below to see your problem text
txt = mx.lab_2_problem_2(student_id)
display(Markdown(txt))
# Out:
# In this problem your task is to plot two functions and
# graphically find the intersection points of the two functions.
#
# The first functions is $$ f(x) = \sqrt{2.8x} $$ and
# the second function is $$ g(x) = (x - 2.75)^2 $$.
#
# First, plot the two functions in the same graph. Make this first plot to show the functions in the
# larger range of $x$ values, say $x \in [0, 10]$.
#
# Then plot the two functions in another graph, but now show the functions in the smaller range of
# $x$ values. In this second plot, make sure to show the intersection points of the two functions.
# What are their values? Find the values *graphically*.
#
# Finally, remember to decorate the plots with title, axis labels, and a legend. Add also grid
# lines to the plots to make them easier to read.

# %% [markdown]
# ### My solution

# %%
# Your code starts here
x = np.arange(0, 6, 0.01)
f = (2.8*x)**0.5
g = (x-2.75)**2
plt.figure()
plt.plot(x, f, label='f(x)')
plt.plot(x, g, label='g(x)')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Overview: Both functions")
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(x, f, label='f(x)')
plt.plot(x, g, label='g(x)')
plt.xlim(1.2, 1.6)
plt.ylim(1.5, 2.5)
plt.title("Intersection Point 1 (zoomed)")
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(x, f, label='f(x)')
plt.plot(x, g, label='g(x)')
plt.xlim(4.5, 4.8)
plt.ylim(2.5, 4.5)
plt.title("Intersection Point 2 (zoomed)")
plt.legend()
plt.grid(True)
plt.show()
